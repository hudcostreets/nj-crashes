# %%
from utz import *
from njsp.paths import CRASHES_PQT, PROJECTED_CSV, ROOT_DIR
from njsp.ytc import to_ytc
from njsp.ytd import oldest_commit_rundate_since, projected_roy_deaths
from njsp import Ytd

# %%
ytd = Ytd()
prv_rundate = ytd.prv_rundate
prv_rundate
# Out:
# '2023-02-02'

# %% [markdown]
# Find the oldest commit with rundate less than 1 year ago, load crashes from that time:

# %%
with cd(ROOT_DIR):
    prv_commit = oldest_commit_rundate_since(prv_rundate)

crashes_relpath = relpath(CRASHES_PQT, ROOT_DIR)
prv_crashes_blob = prv_commit.tree[crashes_relpath]
stream = prv_crashes_blob.data_stream
blob = stream.read()
prv_crashes = read_parquet(BytesIO(blob))
prv_crashes
# Out:
# Searching for oldest commit with rundate ≥2023-02-02
# Found rundate 2023-02-01 10:00:07 < 2023-02-02 at commit 38be41e; returning commit d2491ef
#       CCODE     CNAME MCODE            MNAME HIGHWAY  \
# ACCID
# 1703     01  Atlantic  0102    Atlantic City     446
# 1681     09    Hudson  0910       Union City    None
# 1659     04    Camden  0415  Gloucester Twsp      42
# 1661     20     Union  2004   Elizabeth City     624
# 1664     07     Essex  0714      Newark City      95
# ...     ...       ...   ...              ...     ...
# 12295    15     Ocean  1512       Lacey Twsp       9
# 12294    13  Monmouth  1316    Freehold Twsp       9
# 12308    07     Essex  0714      Newark City    None
# 12303    05  Cape May  0504      Dennis Twsp      47
# 12305    09    Hudson  0906      Jersey City     644
#
#                                      LOCATION  FATALITIES  INJURIES  \
# ACCID
# 1703    State/Interstate Authority 446 S MP 1         1.0       1.0
# 1681          Bergenline Ave S MP 0 at 6th St         1.0       NaN
# 1659                State Highway 42 N MP 8.2         1.0       1.0
# 1661           County 624 W MP 2.2 at Ikea Dr         1.0       1.0
# 1664   State/Interstate Authority 95 S MP 104         1.0       0.0
# ...                                       ...         ...       ...
# 12295                         State Highway 9         1.0       0.0
# 12294                         State Highway 9         1.0       NaN
# 12308                            North 9th St         1.0       2.0
# 12303               State Highway 47 MP 16.85         1.0       0.0
# 12305                              County 644         1.0       NaN
#
#                STREET  FATAL_D  FATAL_P  FATAL_T  FATAL_B                  dt
# ACCID
# 1703             None      NaN      NaN      NaN      NaN 2008-01-01 00:35:00
# 1681   Bergenline Ave      NaN      NaN      NaN      NaN 2008-01-01 04:11:00
# 1659             None      NaN      NaN      NaN      NaN 2008-01-01 06:46:00
# 1661             None      NaN      NaN      NaN      NaN 2008-01-01 12:29:00
# 1664             None      NaN      NaN      NaN      NaN 2008-01-02 09:09:00
# ...               ...      ...      ...      ...      ...                 ...
# 12295            None      1.0      0.0      0.0      0.0 2023-01-30 17:59:00
# 12294            None      0.0      0.0      1.0      0.0 2023-01-30 18:49:00
# 12308    North 9th St      0.0      0.0      1.0      0.0 2023-01-31 17:50:00
# 12303            None      1.0      0.0      0.0      0.0 2023-01-31 19:33:00
# 12305            None      1.0      0.0      0.0      0.0 2023-02-01 06:51:00
#
# [8026 rows x 14 columns]

# %% [markdown]
# Load previous year YTD and final counts, and current year YTD counts:

# %%
prv_year = ytd.prv_year
cur_year = ytd.cur_year

prv_ytc = to_ytc(prv_crashes)
prv_ytd = prv_ytc.loc[prv_year]

cur_ytc = to_ytc(read_parquet(CRASHES_PQT))
prv_end = cur_ytc.loc[prv_year]
cur_ytd = cur_ytc.loc[cur_year]

cur_ytd
# Out:
#             driver  passenger  pedestrian  cyclist  crashes
# county
# Atlantic         2          0           1        0        3
# Bergen           2          0           3        0        5
# Burlington       2          1           0        0        3
# Camden           0          0           3        0        3
# Cumberland       0          0           1        0        1
# Essex            0          0           2        0        2
# Gloucester       1          0           0        0        1
# Hudson           1          0           1        0        2
# Hunterdon        0          0           1        0        1
# Mercer           2          0           0        0        2
# Middlesex        2          2           4        0        6
# Monmouth         1          3           2        0        5
# Ocean            2          0           4        0        6
# Passaic          0          0           1        0        1
# Union            0          0           1        0        1

# %% [markdown]
# Compute fraction of current year that has elapsed (year-to-date; "YTD") and still remains (rest-of-year; "ROY"):

# %%
cur_ytd_frac = ytd.cur_year_frac
cur_roy_frac = 1 - cur_ytd_frac
cur_ytd_frac, cur_roy_frac
# Out:
# (0.08857019075086014, 0.9114298092491399)

# %% [markdown]
# Combine previous year YTD / end with current year YTD:

# %%
def melt(df, name):
    return (
        df
        .melt(ignore_index=False, var_name='type')
        .set_index('type', append=True)
        .value
        .rename(name)
    )

z = sxs(
    melt(prv_ytd, 'prv_ytd'),
    melt(prv_end, 'prv_end'),
    melt(cur_ytd, 'cur_ytd'),
).fillna(0).astype(int)
z
# Out:
#                     prv_ytd  prv_end  cur_ytd
# county     type
# Atlantic   driver         1       17        2
# Bergen     driver         0       21        2
# Camden     driver         1       19        0
# Cape May   driver         1        4        0
# Essex      driver         1       23        0
# ...                     ...      ...      ...
# Burlington crashes        0       34        3
# Cumberland crashes        0       20        1
# Salem      crashes        0       11        0
# Somerset   crashes        0       22        0
# Sussex     crashes        0        6        0
#
# [105 rows x 3 columns]

# %%
def project_roy(r):
    return int(round(projected_roy_deaths(r.prv_ytd, r.prv_end, r.cur_ytd, cur_ytd_frac)))

roy = z.apply(project_roy, axis=1).rename('roy')
projected = (
    (z.cur_ytd + roy)
    .rename('projected')
    .reset_index(level=1)
    .pivot(columns='type', values='projected')
)
projected
# Out:
# type        crashes  cyclist  driver  passenger  pedestrian
# county
# Atlantic         36        2      19          6          12
# Bergen           44        1      23          4          13
# Burlington       37        1      28          5           5
# Camden           41        5      16          5          16
# Cape May          5        0       3          1           2
# Cumberland       20        0      12          5           6
# Essex            43        2      20          4          21
# Gloucester       31        1      20          5           5
# Hudson           25        3      11          3          10
# Hunterdon         4        0       3          0           2
# Mercer           35        0      18          3          10
# Middlesex        59        2      28         12          23
# Monmouth         38        3      18         12           7
# Morris           18        0      12          4           3
# Ocean            47        1      28          6          13
# Passaic          24        0      13          1          10
# Salem            10        0       7          2           2
# Somerset         20        0      13          4           5
# Sussex            5        0       5          2           1
# Union            28        2       9          5          13
# Warren           10        0       7          1           2

# %%
projected.to_csv(PROJECTED_CSV)
