# %%
from utz import *
import plotly.express as px

# %%
nj = concat([
    read_parquet(f'{year}/NewJersey{year}Accidents.pqt')
    for year in range(2017, 2021)
])
nj
# Out:
#        County Code Municipality Code Department Case Number County Name  \
# 0               01                01              1708-0494    ATLANTIC
# 1               01                01              1708-0497    ATLANTIC
# 2               01                01              1709-1131    ATLANTIC
# 3               01                01              1709-1132    ATLANTIC
# 4               01                01              1712-0555    ATLANTIC
# ...            ...               ...                    ...         ...
# 195469          21                23       B150-2020-00350A      WARREN
# 195470          21                23       B150-2020-00354A      WARREN
# 195471          21                23       B150-2020-00361A      WARREN
# 195472          21                23       B150-2020-00369A      WARREN
# 195473          21                23       B150-2020-00383A      WARREN
#
#        Municipality Name Police Dept Code        Police Department  \
# ...

# %%
from utz import *
import plotly.express as px

nj = concat([
    read_parquet(f'{year}/NewJersey{year}Accidents.pqt')
    for year in range(2017, 2021)
])
njhudson = nj[nj['County Name'] == 'HUDSON']
blvd_e = pd.concat([
    hudson[hudson['Crash Location'].str.lower().str.contains('blvd e')],
    hudson[hudson['Crash Location'].str.lower().str.contains('boulevard e')],
])
len(blvd_e)
# Out:
# 73

# %%
blvd_e
# Out:
#        County Code Municipality Code Department Case Number County Name  \
# 129289          09                11        17-11-27-034693      HUDSON
# 129503          09                12          I-2017-012696      HUDSON
# 127359          09                08           SO-18-046877      HUDSON
# 125347          09                08              19-113780      HUDSON
# 125988          09                08              19-148703      HUDSON
# 129222          09                11               19-31176      HUDSON
# 129229          09                11               19-31851      HUDSON
# 129244          09                11               19-32866      HUDSON
# 129248          09                11               19-33215      HUDSON
# 129261          09                11               19-34770      HUDSON
# 129268          09                11               19-35425      HUDSON
# 129335          09                11               19-40727      HUDSON
# ...

# %%
blvd_e['Total Killed'].sum()
# Out:
# 1

# %%
blvd_e['Total Injured'].sum()
# Out:
# 23
