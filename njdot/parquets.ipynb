# %%
from utz import *
from njdot import crashes, drivers, occupants, pedestrians, vehicles
from njdot.load import pk_base, INDEX_NAME, normalize, print_hists

# %%
# %%time
c = crashes.load(write_pqt=True)
c
# Out:
# Loading /Users/ryan/c/neighbor-ryan/nj-crashes/tlgdb_2022_a_34_nj.gdb/
# Computing
# crashes: merging olat/olon with county geometries
# /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/crashes.py:114: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4269
#
#   joined = sjoin(gdf.df[['olat', 'olon', 'geometry']], cg)
# /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/crashes.py:122: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4269
#
#   ij = sjoin(igdf.df[['geometry']], cg)
# CPU times: user 7min 26s, sys: 37.5 s, total: 8min 4s
# Wall time: 8min 29s
# Wrote /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet (6077303 rows, 346.8 MB)
#                          dt  year  cc  mc              case pdc  \
# id
# 0       2001-12-21 18:34:00  2001   1   1       #2001-17846  01
# 1       2001-01-01 09:30:00  2001   1   1          01-00029   1
# 2       2001-04-10 14:44:00  2001   1   1         01-004615   1
# 3       2001-04-15 13:56:00  2001   1   1         01-004880   1
# 4       2001-04-16 10:29:00  2001   1   1         01-004912   1
# ...                     ...   ...  ..  ..               ...  ..
# 6077298 2021-05-26 21:08:00  2021  21  23  B150-2021-00117A  02
# 6077299 2021-05-25 07:26:00  2021  21  23  B150-2021-00118A  02
# 6077300 2021-06-03 20:17:00  2021  21  23  B150-2021-00128A  02
# 6077301 2021-06-06 00:00:00  2021  21  23  B150-2021-00130A  02
# 6077302 2021-06-06 19:33:00  2021  21  23  B150-2021-00132A  02
#
#                              pdn          station  tk  ti  pk  pi severity  \
# id
# 0                   Absecon City  MUNICIPAL COMP?   0   0   0   0        p
# 1                        Absecon                    0   0   0   0        p
# 2                        Absecon                    0   4   0   0        i
# 3                        Absecon                    0   1   0   0        i
# 4                        Absecon                    0   0   0   0        p
# ...                          ...              ...  ..  ..  ..  ..      ...
# 6077298  New Jersey State Police  WASHINGTON - SQ   0   0   0   0        p
# 6077299  New Jersey State Police  WASHINGTON - SQ   0   0   0   0        p
# 6077300  New Jersey State Police  WASHINGTON - SQ   0   0   0   0        p
# 6077301  New Jersey State Police  WASHINGTON - SQ   0   0   0   0        p
# 6077302  New Jersey State Police  WASHINGTON - SQ   0   0   0   0        p
#
#         Intersection  alcohol  hazmat  crash_type  tv  \
# id
# 0                  B    False   False           3   2
# 1                  B    False   False           6   2
# 2                  I    False   False           3   2
# 3                  B    False   False           1   2
# 4                  I    False   False           1   2
# ...              ...      ...     ...         ...  ..
# 6077298            I    False   False          11   1
# 6077299            I    False   False           1   2
# 6077300            B    False   False          12   1
# 6077301            B    False   False          12   1
# 6077302            B    False   False           3   2
#
#                                            road road_direction  route  \
# id
# 0                               CALDERON AVENUE                  <NA>
# 1                                    RITZ DRIVE                  <NA>
# 2                                 MORTON AVENUE                  <NA>
# 3                                         RT 30                    30
# 4                                        CR 651                   651
# ...                                         ...            ...    ...
# 6077298                       WARREN COUNTY 620              N    620
# 6077299  MANUNKA CHUNK RD / UPPER SEREPTA RD **              W   <NA>
# 6077300                               ROUTE 519              S    519
# 6077301                                   US 46              E     46
# 6077302                           FIELDSTONE CT              W   <NA>
#
#         Route Suffix         sri         mp  road_system  road_character  \
# id
# 0                                       NaN            7               2
# 1                                       NaN            7               1
# 2                                       NaN            7               1
# 3                     00000030__  51.099998            2               1
# 4                                       NaN            5               2
# ...              ...         ...        ...          ...             ...
# 6077298               21000620__   0.000000            5            <NA>
# 6077299               21231034__   1.730000            7            <NA>
# 6077300               00000519__  44.000000            5            <NA>
# 6077301               00000046__   7.500000            2            <NA>
# 6077302                                 NaN            7            <NA>
#
#          road_surface  surface_condition  light_condition  env_condition  \
# id
# 0                   2                  1                6              1
# 1                   2                  3                6              1
# 2                   2                  1                1              1
# 3                   2                  1                1              1
# 4                   2                  2                1              2
# ...               ...                ...              ...            ...
# 6077298             2                  1                6              1
# 6077299             2                  1                1              1
# 6077300             2                  2                5              4
# 6077301             2                  1                7              1
# 6077302             5                  1                1              1
#
#          road_divided  ttcz  cross_street_distance Unit Of Measurement  \
# id
# 0                   5     1                    100                  FE
# 1                   5     1                   <NA>
# 2                   5     1                   <NA>                  AT
# 3                   5     1                   <NA>
# 4                   5     1                   <NA>                  AT
# ...               ...   ...                    ...                 ...
# 6077298             5     1                   <NA>                  AT
# 6077299             5     1                   <NA>                  AT
# 6077300             5     1                   <NA>
# 6077301             5     1                   <NA>
# 6077302             5     1                   <NA>
#
#         Direction From Cross Street                  cross_street Is Ramp  \
# id
# 0                                 N                         RT 30
# 1
# 2                                                 NEW YORK AVENUE
# 3
# 4                                                          CR 630
# ...                             ...                           ...     ...
# 6077298                              ROUTE 519 / S BRIDGEVILLE RD
# 6077299                                             MASSENATTS RD
# 6077300
# 6077301
# 6077302                                       130 COUNTY ROAD 519
#
#         ramp_route Ramp To/From Route Direction  speed_limit  \
# id
# 0                                                         25
# 1                                                         25
# 2                                                         25
# 3                                                         45
# 4                                                         35
# ...            ...                          ...          ...
# 6077298                                                   50
# 6077299                                                   40
# 6077300                                                   50
# 6077301                                                   50
# 6077302                                                   15
#
#          speed_limit_cross      olat      olon  cell_phone  \
# id
# 0                     <NA>       NaN       NaN       False
# 1                     <NA>       NaN       NaN       False
# 2                     <NA>       NaN       NaN       False
# 3                     <NA>       NaN       NaN       False
# 4                     <NA>       NaN       NaN       False
# ...                    ...       ...       ...         ...
# 6077298                 50  40.80707 -75.07559       False
# 6077299                 50  40.84466 -75.05549       False
# 6077300               <NA>  40.80564 -75.07627       False
# 6077301               <NA>  40.84149 -75.04968       False
# 6077302                  5  40.81220 -75.04940       False
#
#                                      Other Property Damage  \
# id
# 0        NEVER SAW V-1 MINOR DAMAGE - NO INJURIES REPOR...
# 1
# 2
# 3                   WITNESS-PETRIA GIBSON AND ANGELO HERSH
# 4        *BETH VEHICLES-RELIANCE INSURANCE CO.(215)864-...
# ...                                                    ...
# 6077298          Damage to 10ft of Country road guardrail.
# 6077299
# 6077300
# 6077301
# 6077302
#
#         Reporting Badge No.  horizontal_alignment  road_grade  \
# id
# 0                       830                  <NA>        <NA>
# 1                       836                  <NA>        <NA>
# 2                       836                  <NA>        <NA>
# 3                       886                  <NA>        <NA>
# 4                       836                  <NA>        <NA>
# ...                     ...                   ...         ...
# 6077298                7837                     2           4
# 6077299                8610                     1           4
# 6077300                8514                     3           4
# 6077301                8365                     1           4
# 6077302                8395                     1           4
#
#          first_harmful_event                    geometry   occ reason  \
# id
# 0                       <NA>                 POINT EMPTY  <NA>  No MP
# 1                       <NA>                 POINT EMPTY  <NA>  No MP
# 2                       <NA>                 POINT EMPTY  <NA>  No MP
# 3                       <NA>  POINT (-74.51231 39.43271)  <NA>    NaN
# 4                       <NA>                 POINT EMPTY  <NA>  No MP
# ...                      ...                         ...   ...    ...
# 6077298                   46  POINT (-75.07561 40.80716)    21    NaN
# 6077299                   26  POINT (-75.05612 40.84434)    21    NaN
# 6077300                   24  POINT (-75.01515 40.86311)    21    NaN
# 6077301                   24  POINT (-75.04640 40.84042)    21    NaN
# 6077302                   26                 POINT EMPTY    21  No MP
#
#               ilon       ilat   icc
# id
# 0              NaN        NaN  <NA>
# 1              NaN        NaN  <NA>
# 2              NaN        NaN  <NA>
# 3       -74.512308  39.432705     1
# 4              NaN        NaN  <NA>
# ...            ...        ...   ...
# 6077298 -75.075607  40.807156    21
# 6077299 -75.056122  40.844345    21
# 6077300 -75.015149  40.863108    21
# 6077301 -75.046404  40.840421    21
# 6077302        NaN        NaN  <NA>
#
# [6077303 rows x 55 columns]

# %%
assert (c[pk_base].sort_values(pk_base) == c[pk_base]).all().all()

# %%
# %%time
d = drivers.load(write_pqt=True)
d
# Out:
# Computing
# Merging drivers with crashes
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet
# CPU times: user 1min 13s, sys: 10.2 s, total: 1min 24s
# Wall time: 1min 25s
# Wrote /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/drivers.parquet (11450826 rows, 206.5 MB)
#           crash_id  vn            city state    zip license_state         dob  \
# id
# 0                0   1  GALLOWAY TWSP.    NJ  08205            NJ  02/06/1963
# 1                0   2   ATLANTIC CITY    NJ  08401            NJ  06/30/1938
# 2                1   1
# 3                1   2
# 4                2   1         ABSECON    NJ  08201            NJ  07/03/1971
# ...            ...  ..             ...   ...    ...           ...         ...
# 11450821   6077299   2       BELVIDERE    NJ  07823            NJ
# 11450822   6077300   1         LANDING    NJ  07850            NJ
# 11450823   6077301   1       BELVIDERE    NJ  07823            NJ
# 11450824   6077302   1    PHILLIPSBURG    NJ  08865            NJ
# 11450825   6077302   2       BELVIDERE    NJ  07823            NJ
#
#          sex alc_test_given alc_test_type alc_test_results  \
# id
# 0          M              N
# 1          F              N
# 2
# 3                         N
# 4          F              N
# ...       ..            ...           ...              ...
# 11450821   F              N
# 11450822   M              N
# 11450823   M              N
# 11450824   M              N
# 11450825   F              N
#
#                            charge1 summons1  status1 charge2 summons2 charge3  \
# id
# 0                                                  1
# 1                39:4-144 #A046899                 1
# 2                                               <NA>
# 3                                                  0
# 4         39:3-76.2E (2) A046071 2                 1
# ...                            ...      ...      ...     ...      ...     ...
# 11450821                                        <NA>
# 11450822                                        <NA>
# 11450823                                        <NA>
# 11450824                                        <NA>
# 11450825                                        <NA>
#
#          summons3 charge4 summons4  status2
# id
# 0                                      <NA>
# 1                                      <NA>
# 2                                      <NA>
# 3                                      <NA>
# 4                                      <NA>
# ...           ...     ...      ...      ...
# 11450821                               <NA>
# 11450822                               <NA>
# 11450823                               <NA>
# 11450824                               <NA>
# 11450825                               <NA>
#
# [11450826 rows x 21 columns]

# %%
# %%time
p = pedestrians.load(write_pqt=True)
p
# Out:
# Computing
# Merging pedestrians with crashes
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet
# CPU times: user 10.4 s, sys: 1.09 s, total: 11.5 s
# Wall time: 11.6 s
# Wrote /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/pedestrians.parquet (178521 rows, 4.6 MB)
#         crash_id  pn  condition             city state    zip         dob  \
# id
# 0              7   1          3          ABSECON    NJ  08201  07/28/1990
# 1             48  31          3          ABSECON    NJ  08201  01/16/1967
# 2             76   1          2  EGG HARBOR TWP.    NJ  08234  11/16/1952
# 3            114   1          4    GALLOWAY TWP.    NJ  08205  03/31/1959
# 4            236   1          4          ABSECON    NJ  08201  04/18/1953
# ...          ...  ..        ...              ...   ...    ...         ...
# 178516   6076961   1          4       WASHINGTON    NJ  07882
# 178517   6076969  31          3       WASHINGTON    NJ  07882
# 178518   6076973   1          1      PORT MURRAY    NJ  07865
# 178519   6077021   1          2       WASHINGTON    NJ  07882
# 178520   6077192   1          3     ROSELLE PARK    NJ  07204
#
#         age sex alc_test_given alc_test_type alc_test_results   charge1  \
# id
# 0        10   M
# 1        34   M
# 2        48   F              N
# 3        42   F              N                                 SUBPOENA
# 4        48   M              N
# ...     ...  ..            ...           ...              ...       ...
# 178516   74   F              N
# 178517   17   M              N
# 178518   59   M              N
# 178519   65   M              N
# 178520   24   M
#
#        summons1  traffic_controls  cir1  cir2   dir   act  inj_loc  inj_type  \
# id
# 0                            <NA>  <NA>  <NA>  <NA>    41        1         5
# 1                            <NA>  <NA>  <NA>  <NA>  <NA>        1         4
# 2                            <NA>  <NA>  <NA>  <NA>    46       12         3
# 3                            <NA>  <NA>  <NA>  <NA>    49        7      <NA>
# 4                            <NA>  <NA>  <NA>  <NA>    43        1         4
# ...         ...               ...   ...   ...   ...   ...      ...       ...
# 178516                          5    25  <NA>     3    43        6         8
# 178517                          4    25  <NA>     2     3       11         5
# 178518                          4    73    89     0    36       12         3
# 178519                         11    89  <NA>     3    42       12         3
# 178520                       <NA>  <NA>  <NA>  <NA>  <NA>        7         5
#
#         med_refused  safety_used hospital  status1  cyclist  other charge2  \
# id
# 0              <NA>         <NA>                 1    False  False
# 1              <NA>         <NA>              <NA>     True  False
# 2              <NA>         <NA>                 1    False  False
# 3              <NA>         <NA>                 1    False  False
# 4              <NA>         <NA>                 1    False  False
# ...             ...          ...      ...      ...      ...    ...     ...
# 178516            2            1     7102        1    False  False
# 178517            1            8                 1     True  False
# 178518         <NA>         <NA>     7102        2    False  False
# 178519            2         <NA>       99        1    False  False
# 178520            0         <NA>     7102     <NA>    False  False
#
#        summons2 charge3 summons3 charge4 summons4  status2
# id
# 0                                                     <NA>
# 1                                                     <NA>
# 2                                                     <NA>
# 3                                                     <NA>
# 4                                                     <NA>
# ...         ...     ...      ...     ...      ...      ...
# 178516                                                <NA>
# 178517                                                <NA>
# 178518                                                <NA>
# 178519                                                <NA>
# 178520                                                <NA>
#
# [178521 rows x 34 columns]

# %%
# %%time
v = vehicles.load(write_pqt=True)
v
# Out:
# Computing
# Merging vehicles with crashes
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet
# CPU times: user 1min 53s, sys: 11 s, total: 2min 4s
# Wall time: 2min 7s
# Wrote /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/vehicles.parquet (11450826 rows, 245.1 MB)
#           crash_id  vn  ins_co owner_state             make           model  \
# id
# 0                0   1     426          NJ    NISSAN MAXIMA
# 1                0   2     989          NJ  LINCOLN TOWNCAR
# 2                1   1     962          NJ       TOYOTA 4DR
# 3                1   2    <NA>
# 4                2   1      85          NJ    CHEVY CORSICA
# ...            ...  ..     ...         ...              ...             ...
# 11450821   6077299   2     962          NJ          HYUNDAI          SONATA
# 11450822   6077300   1     134          NJ           SUBARU       FORRESTER
# 11450823   6077301   1     148          NJ           TOYOTA         COROLLA
# 11450824   6077302   1     134          NJ          HYUNDAI          SONATA
# 11450825   6077302   2     962          NJ             JEEP  GRAND CHEROKEE
#
#          color    vy state towed  rm_by  imp_loc  dmg_loc  type  body  cir1  \
# id
# 0          BUR  1991    NJ     D   <NA>        8        7     1  <NA>    25
# 1           BK  1996    NJ     D      2       12       12     6     0     4
# 2          GRN  1997    NJ     D      1       11     <NA>     1  <NA>    25
# 3                  0               <NA>        0        0     5     0     2
# 4          PUR  1996    NJ     T      3        8       15     1  <NA>    25
# ...        ...   ...   ...   ...    ...      ...      ...   ...   ...   ...
# 11450821    BK  2012    NJ            2        6        6     1  <NA>    25
# 11450822    SL  2015    NJ            1       11       11     4  <NA>    57
# 11450823    BK  2009    NJ            1       11       11     1  <NA>    57
# 11450824    BL  2013    NJ            1        1        1     1  <NA>     4
# 11450825    BL  2017    NJ            2       11       11     1  <NA>    25
#
#           cir2  dir  act  ev1   ev2   ev3   ev4  oversize  hit_run  dep   dmg  \
# id
# 0         <NA>    1    3   26  <NA>  <NA>  <NA>      <NA>    False  NaN  <NA>
# 1         <NA>    2    3   26  <NA>  <NA>  <NA>         0    False  NaN  <NA>
# 2         <NA>    3   10   28  <NA>  <NA>  <NA>      <NA>    False  NaN  <NA>
# 3         <NA>    1    1   26  <NA>  <NA>  <NA>         0    False  NaN  <NA>
# 4         <NA>    3    1   26     1  <NA>  <NA>      <NA>    False  NaN  <NA>
# ...        ...  ...  ...  ...   ...   ...   ...       ...      ...  ...   ...
# 11450821  <NA>    4    3   26  <NA>  <NA>  <NA>      <NA>    False    1     3
# 11450822  <NA>    3    1   24  <NA>  <NA>  <NA>         2    False    1     3
# 11450823  <NA>    2    1   24  <NA>  <NA>  <NA>      <NA>    False    1     3
# 11450824  <NA>    4    1   26  <NA>  <NA>  <NA>      <NA>    False    1     2
# 11450825  <NA>    3    1   26  <NA>  <NA>  <NA>      <NA>    False    1     2
#
#             ev
# id
# 0         <NA>
# 1         <NA>
# 2         <NA>
# 3         <NA>
# 4         <NA>
# ...        ...
# 11450821    26
# 11450822    24
# 11450823    24
# 11450824    26
# 11450825    26
#
# [11450826 rows x 28 columns]

# %%
# %%time
o = occupants.load(write_pqt=True)
o
# Out:
# Computing
# Merging occupants with crashes
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet
# Crash 12410270: fixing bad vehicle num, 25 → 2
# Merging occupants with vehicles
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/vehicles.parquet
# CPU times: user 1min 26s, sys: 8.82 s, total: 1min 35s
# Wall time: 1min 36s
# Wrote /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/occupants.parquet (13756726 rows, 215.7 MB)
#           crash_id  vehicle_id  on  condition   pos  eject   age sex  inj_loc  \
# id
# 0                0           0   1       <NA>     1      1    38   M     <NA>
# 1                0           1   2       <NA>     1      1    63   F     <NA>
# 2                1           2   1       <NA>  <NA>   <NA>  <NA>         <NA>
# 3                2           4   1          3     1      1    29   F        6
# 4                2           4   2          3     3      1     7   M        8
# ...            ...         ...  ..        ...   ...    ...   ...  ..      ...
# 13756721   6077301    11450823   1          5     1      1    74   M     <NA>
# 13756722   6077302    11450824   1          5     1      1    23   M     <NA>
# 13756723   6077302    11450824   2          5     3      1    23   F     <NA>
# 13756724   6077302    11450824   3          5     6      1    25   M     <NA>
# 13756725   6077302    11450825   4          5     1      1    17   F     <NA>
#
#           inj_type med_refused  safety_avail  safety_used  airbag hospital
# id
# 0             <NA>                         4            4    <NA>
# 1             <NA>                         4            4    <NA>
# 2             <NA>                      <NA>         <NA>    <NA>
# 3                8                         4            4    <NA>
# 4                5                         4            4    <NA>
# ...            ...         ...           ...          ...     ...      ...
# 13756721      <NA>          01            11            4    <NA>
# 13756722      <NA>                        11            4    <NA>
# 13756723      <NA>                        11            4    <NA>
# 13756724      <NA>                        11            4    <NA>
# 13756725      <NA>                        11            4    <NA>
#
# [13756726 rows x 15 columns]
