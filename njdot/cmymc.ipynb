# %% [markdown]
# # {County, Muni, Year, Month} aggregation
#
# - Group crashes by {County, Muni, Year, Month}
# - Compute sums of {fatal,injury,property} x {victims,crashes}
# - Save SQLite (in `www` dir, for use by dev web server)
# - Upload to S3 (`s3://nj-crashes/njdot/data/cmymc.db`)

# %%
from utz import *
from njdot import crashes, vehicles, occupants, pedestrians
from njdot.paths import CMYMC_DB
from nj_crashes.utils import sql

# %%
# %%time
c = crashes.load(cols=['dt', 'year', 'cc', 'mc', 'severity', 'tk', 'ti', 'pk', 'pi', ])
y = c.year.rename('y')
m = c.dt.dt.month.rename('m')
c = sxs(y, m, c[[k for k in c if k not in ['y', 'm', 'year', 'dt']]])
c
# Out:
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/crashes.parquet
# CPU times: user 446 ms, sys: 160 ms, total: 605 ms
# Wall time: 536 ms
#             y   m  cc  mc severity  tk  ti  pk  pi
# id
# 0        2001  12   1   1        p   0   0   0   0
# 1        2001   1   1   1        p   0   0   0   0
# 2        2001   4   1   1        i   0   4   0   0
# 3        2001   4   1   1        i   0   1   0   0
# 4        2001   4   1   1        p   0   0   0   0
# ...       ...  ..  ..  ..      ...  ..  ..  ..  ..
# 6319789  2022  12  21  23        p   0   0   0   0
# 6319790  2022  12  21  23        p   0   0   0   0
# 6319791  2022  12  21  23        p   0   0   0   0
# 6319792  2022  12  21  23        p   0   0   0   0
# 6319793  2022  12  21  23        i   0   1   0   0
#
# [6319794 rows x 9 columns]

# %%
cmym_cols = [ 'cc', 'mc', 'y', 'm', ]
cmymtc_cols = cmym_cols + [ 'condition', 'type', ]

# %%
p = pedestrians.load()
p
# Out:
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/pedestrians.parquet
#         crash_id  pn  condition             city state    zip         dob  \
# id
# 0              7   1          3          ABSECON    NJ  08201  07/28/1990
# 1             48  31          3          ABSECON    NJ  08201  01/16/1967
# 2             76   1          2  EGG HARBOR TWP.    NJ  08234  11/16/1952
# 3            114   1          4    GALLOWAY TWP.    NJ  08205  03/31/1959
# 4            236   1          4          ABSECON    NJ  08201  04/18/1953
# ...          ...  ..        ...              ...   ...    ...         ...
# 185444   6319317   1          4     PHILLIPSBURG    NJ  08865
# 185445   6319399   1          5        BELVIDERE    NJ  07823
# 185446   6319407  31          2       WASHINGTON    NJ  07882
# 185447   6319412   1          1       WASHINGTON    NJ  07882
# 185448   6319505   1          2       WASHINGTON    NJ  07882
#
#         age sex alc_test_given alc_test_type alc_test_results   charge1  \
# id
# 0        10   M
# 1        34   M
# 2        48   F              N
# 3        42   F              N                                 SUBPOENA
# 4        48   M              N
# ...     ...  ..            ...           ...              ...       ...
# 185444   31   M              N
# 185445   16   M              N
# 185446   12   M              N
# 185447   55   M              N
# 185448   63   F              N
#
#        summons1  traffic_controls  cir1  cir2   dir   act  inj_loc  inj_type  \
# id
# 0                            <NA>  <NA>  <NA>  <NA>    41        1         5
# 1                            <NA>  <NA>  <NA>  <NA>  <NA>        1         4
# 2                            <NA>  <NA>  <NA>  <NA>    46       12         3
# 3                            <NA>  <NA>  <NA>  <NA>    49        7      <NA>
# 4                            <NA>  <NA>  <NA>  <NA>    43        1         4
# ...         ...               ...   ...   ...   ...   ...      ...       ...
# 185444                         11    75    72     1    42        0         0
# 185445                       <NA>    78  <NA>  <NA>    42        8         8
# 185446                         11    25  <NA>     3     1       11         7
# 185447                          4    78  <NA>     1    46        1         3
# 185448                       <NA>    85    85  <NA>  <NA>       12         3
#
#         med_refused  safety_used hospital  status1  cyclist  other charge2  \
# id
# 0              <NA>         <NA>                 1    False  False
# 1              <NA>         <NA>              <NA>     True  False
# 2              <NA>         <NA>                 1    False  False
# 3              <NA>         <NA>                 1    False  False
# 4              <NA>         <NA>                 1    False  False
# ...             ...          ...      ...      ...      ...    ...     ...
# 185444            2         <NA>     7102        7    False  False
# 185445            1         <NA>                 1    False  False
# 185446            2            1     7102        1     True  False
# 185447            2            1     6404        7    False  False
# 185448            2         <NA>     6404        1    False  False
#
#        summons2 charge3 summons3 charge4 summons4  status2
# id
# 0                                                     <NA>
# 1                                                     <NA>
# 2                                                     <NA>
# 3                                                     <NA>
# 4                                                     <NA>
# ...         ...     ...      ...     ...      ...      ...
# 185444                                                   6
# 185445                                                <NA>
# 185446                                                <NA>
# 185447                                                <NA>
# 185448                                                <NA>
#
# [185449 rows x 34 columns]

# %%
pm = p.merge(c, left_on='crash_id', right_index=True, how='left', validate='m:1')
pm = pm[(pm.condition >= 1) & (pm.condition <= 5)]
pm.loc[ pm.cyclist, 'type'] = 'b'
pm.loc[~pm.cyclist, 'type'] = 't'
pg = pm.groupby(cmymtc_cols).size().rename('num')
pg
# Out:
# cc  mc  y     m   condition  type
# 1   1   2001  1   4          t       1
#               6   3          t       1
#                   4          t       1
#               7   4          b       1
#               9   3          b       1
#                                     ..
# 21  23  2012  7   4          b       1
#         2016  4   1          b       1
#         2017  8   4          b       1
#         2019  7   2          b       1
#         2020  12  1          t       1
# Name: num, Length: 84477, dtype: int64

# %%
o = occupants.load()
o
# Out:
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/occupants.parquet
#           crash_id  vehicle_id  on  condition   pos  eject   age sex  inj_loc  \
# id
# 0                0         0.0   1       <NA>     1      1    38   M     <NA>
# 1                0         1.0   2       <NA>     1      1    63   F     <NA>
# 2                1         2.0   1       <NA>  <NA>   <NA>  <NA>         <NA>
# 3                2         4.0   1          3     1      1    29   F        6
# 4                2         4.0   2          3     3      1     7   M        8
# ...            ...         ...  ..        ...   ...    ...   ...  ..      ...
# 14300194   6319792         NaN   2          5     3      1    48   F     <NA>
# 14300195   6319792         NaN   3          5     3      1    48   F     <NA>
# 14300196   6319792         NaN   4          5     1      1    24   F     <NA>
# 14300197   6319793         NaN   1          5     1      1    77   M     <NA>
# 14300198   6319793         NaN   2          4     1      1    90   M     <NA>
#
#           inj_type med_refused  safety_avail  safety_used  airbag hospital
# id
# 0             <NA>                         4            4    <NA>
# 1             <NA>                         4            4    <NA>
# 2             <NA>                      <NA>         <NA>    <NA>
# 3                8                         4            4    <NA>
# 4                5                         4            4    <NA>
# ...            ...         ...           ...          ...     ...      ...
# 14300194      <NA>                        11            4    <NA>
# 14300195      <NA>                        11            4    <NA>
# 14300196      <NA>                        11            4    <NA>
# 14300197      <NA>                        11            4    <NA>
# 14300198      <NA>          00            11           11       1
#
# [14300199 rows x 15 columns]

# %%
om = o.merge(c, left_on='crash_id', right_index=True, how='left', validate='m:1')
om = om[(om.condition >= 1) & (om.condition <= 5)]
om['type'] = nan
om.loc[om.pos == 1, 'type'] = 'd'
om.loc[om.pos > 1, 'type'] = 'o'
om = om[~om.type.isna()]
og = om.groupby(cmymtc_cols).size().rename('num')
og
# Out:
# /var/folders/dc/gqj_cd8d0d9c1nppd5_yl7bc0000gn/T/ipykernel_10637/3748009522.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'd' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   om.loc[om.pos == 1, 'type'] = 'd'
# cc  mc  y     m   condition  type
# 1   1   2001  1   3          d        3
#                   4          d        6
#                              o        4
#               2   2          d        1
#                   4          d        6
#                                      ..
# 21  23  2022  12  3          d        1
#                   4          d        3
#                              o        1
#                   5          d       21
#                              o        5
# Name: num, Length: 383262, dtype: int64

# %%
g = pd.concat([ pg, og ]).sort_index()
g
# Out:
# cc  mc  y     m   condition  type
# 1   1   2001  1   3          d        3
#                   4          d        6
#                              o        4
#                              t        1
#               2   2          d        1
#                                      ..
# 21  23  2022  12  3          d        1
#                   4          d        3
#                              o        1
#                   5          d       21
#                              o        5
# Name: num, Length: 467739, dtype: int64

# %%
occ_severity = om.groupby('crash_id')['condition'].min().rename('occ_severity')
ped_severity = pm.groupby('crash_id')['condition'].min().rename('ped_severity')
sev = sxs(occ_severity, ped_severity).min(axis=1).rename('condition')
cs = sxs(c.drop(columns='severity'), sev)
cs['condition'] = cs.condition.fillna(5)
cs
# Out:
#             y   m  cc  mc  tk  ti  pk  pi  condition
# 0        2001  12   1   1   0   0   0   0          5
# 1        2001   1   1   1   0   0   0   0          5
# 2        2001   4   1   1   0   4   0   0          3
# 3        2001   4   1   1   0   1   0   0          4
# 4        2001   4   1   1   0   0   0   0          5
# ...       ...  ..  ..  ..  ..  ..  ..  ..        ...
# 6319789  2022  12  21  23   0   0   0   0          5
# 6319790  2022  12  21  23   0   0   0   0          5
# 6319791  2022  12  21  23   0   0   0   0          5
# 6319792  2022  12  21  23   0   0   0   0          5
# 6319793  2022  12  21  23   0   1   0   0          4
#
# [6319794 rows x 9 columns]

# %%
cxs = cs.groupby(cmym_cols + ['condition']).size().rename('num_crashes')
cxs
# Out:
# cc  mc  y     m   condition
# 1   1   2001  1   3             2
#                   4             8
#                   5            10
#               2   2             1
#                   4             5
#                                ..
# 21  23  2022  11  5             9
#               12  2             1
#                   3             1
#                   4             2
#                   5            13
# Name: num_crashes, Length: 374555, dtype: int64

# %%
cmymc = g.reset_index(level=5).pivot(columns='type', values='num')[['d', 'o', 't', 'b']].rename(columns={
    'd': 'drivers',
    'o': 'passengers',
    't': 'pedestrians',
    'b': 'cyclists',
})
cmymc = sxs(cmymc, cxs).fillna(0).astype(int)
cmymc
# Out:
#                          drivers  passengers  pedestrians  cyclists  \
# cc mc y    m  condition
# 1  1  2001 1  3                3           0            0         0
#               4                6           4            1         0
#            2  2                1           0            0         0
#               4                6           2            0         0
#            3  3                2           1            0         0
# ...                          ...         ...          ...       ...
# 21 23 2018 8  5                0           0            0         0
#            9  5                0           0            0         0
#            10 5                0           0            0         0
#            11 5                0           0            0         0
#            12 5                0           0            0         0
#
#                          num_crashes
# cc mc y    m  condition
# 1  1  2001 1  3                    2
#               4                    8
#            2  2                    1
#               4                    5
#            3  3                    2
# ...                              ...
# 21 23 2018 8  5                    8
#            9  5                   10
#            10 5                   16
#            11 5                   21
#            12 5                    9
#
# [378481 rows x 5 columns]

# %%
hc = cmymc.loc[9].reset_index()
hcf = hc[hc.condition == 1]
hcf
# Out:
#       mc     y   m  condition  drivers  passengers  pedestrians  cyclists  \
# 6      1  2001   3          1        2           0            0         0
# 16     1  2001   7          1        2           0            0         0
# 32     1  2001  12          1        1           0            0         0
# 74     1  2003   5          1        0           0            1         0
# 130    1  2005   1          1        0           0            1         0
# ...   ..   ...  ..        ...      ...         ...          ...       ...
# 7324  12  2019   5          1        0           0            1         0
# 7329  12  2019   6          1        0           1            0         0
# 7403  12  2021   5          1        0           0            1         0
# 7422  12  2021  10          1        0           0            1         0
# 7429  12  2021  12          1        0           0            0         1
#
#       num_crashes
# 6               2
# 16              2
# 32              1
# 74              1
# 130             1
# ...           ...
# 7324            1
# 7329            1
# 7403            1
# 7422            1
# 7429            1
#
# [408 rows x 9 columns]

# %%
hcf.sum()
# Out:
# mc               2662
# y              820673
# m                2673
# condition         408
# drivers           199
# passengers         79
# pedestrians       208
# cyclists           20
# num_crashes       480
# dtype: Int64

# %%
# %%time
sql.write(
    cmymc, 'cmymc', CMYMC_DB,
    idxs=[('cc', 'mc', 'y', 'm', 'condition')],
    rm=True,
    page_size=2**16,
)
# Out:
# Removing /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db
# Writing 378481 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cmymc)
# Wrote DB: 30752768 bytes
# After indices: 37879808 bytes
# CPU times: user 2.38 s, sys: 296 ms, total: 2.68 s
# Wall time: 2.78 s
# After setting page_size=65536 and vacuum: 36241408 bytes

# %%
def sum_idx_col(df0, col, tbl_suffix='', page_size=None):
    idx_cols0 = df0.index.names
    idx_cols1 = [ c for c in idx_cols0 if c != col ]
    assert len(idx_cols1) + 1 == len(idx_cols0)
    df1 = df0.reset_index().drop(columns=col).groupby(idx_cols1).sum()
    tbl = ''.join([ c[0] for c in idx_cols1 ]) + tbl_suffix
    sql.write(
        df1, tbl, CMYMC_DB,
        idxs=[tuple(idx_cols1)],
        replace=False,
        page_size=page_size,
    )
    return df1

# %%
cmyc = sum_idx_col(cmymc, 'm')
cmyc
# Out:
# Writing 49508 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cmyc)
# Wrote DB: 39911424 bytes
# After indices: 40828928 bytes
#                       drivers  passengers  pedestrians  cyclists  num_crashes
# cc mc y    condition
# 1  1  2001 1                1           1            0         0            2
#            2                4           4            1         0            5
#            3               26           8            1         1           27
#            4               90          53            3         1           94
#            5                0           0            0         0          184
# ...                       ...         ...          ...       ...          ...
# 21 23 2022 1                1           0            0         0            1
#            2                3           0            0         0            3
#            3               12           1            0         0           12
#            4               13           2            0         0           11
#            5              146          30            0         0          101
#
# [49508 rows x 5 columns]

# %%
cymc = sum_idx_col(cmymc, 'mc')
cymc
# Out:
# Writing 26623 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cymc)
# Wrote DB: 42991616 bytes
# After indices: 43515904 bytes
#                       drivers  passengers  pedestrians  cyclists  num_crashes
# cc y    m  condition
# 1  2001 1  1                0           0            2         0            2
#            2               10           5            3         0           12
#            3               44          17            4         1           55
#            4              155          86            9         5          164
#            5                0           0            0         0          496
# ...                       ...         ...          ...       ...          ...
# 21 2022 12 1                1           0            0         0            1
#            2                2           0            0         0            2
#            3               16           4            0         0           16
#            4               21           7            0         0           21
#            5              201          53            0         0          148
#
# [26623 rows x 5 columns]

# %%
ymc = sum_idx_col(cymc, 'cc')
ymc
# Out:
# Writing 1320 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (ymc)
# Wrote DB: 43778048 bytes
# After indices: 43843584 bytes
#                    drivers  passengers  pedestrians  cyclists  num_crashes
# y    m  condition
# 2001 1  1               24           9            8         1           41
#         2              144          50           34         2          182
#         3             1048         390          150        20         1262
#         4             5121        2129          336        37         5187
#         5                0           0            0         0        22225
# ...                    ...         ...          ...       ...          ...
# 2022 12 1               29           5           21         1           53
#         2              171          48           48         5          239
#         3             1546         462          194        38         1718
#         4             2635         926          180        38         2673
#         5            24566        7973           21        14        17634
#
# [1320 rows x 5 columns]

# %%
cyc = sum_idx_col(cymc, 'm')
cyc
# Out:
# Writing 2310 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cyc)
# Wrote DB: 44105728 bytes
# After indices: 44171264 bytes
#                    drivers  passengers  pedestrians  cyclists  num_crashes
# cc y    condition
# 1  2001 1               38          14           14         5           65
#         2              119          48           28         8          158
#         3              617         274           72        47          756
#         4             1982        1157           93        70         2121
#         5                0           0            0         0         6639
# ...                    ...         ...          ...       ...          ...
# 21 2022 1               11           4            1         0           16
#         2               33           7            6         1           35
#         3              216          42            1         0          205
#         4              203          76            3         2          205
#         5             2256         750            1         0         1692
#
# [2310 rows x 5 columns]

# %%
yc = sum_idx_col(cyc, 'cc')
yc
# Out:
# Writing 110 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (yc)
# Wrote DB: 44367872 bytes
# After indices: 44433408 bytes
#                 drivers  passengers  pedestrians  cyclists  num_crashes
# y    condition
# 2001 1              418         158          118        23          662
#      2             1899         661          427       124         2595
#      3            13972        5609         1931       958        17718
#      4            58388       27542         3514      1384        60004
#      5                0           0            0         0       231717
# ...                 ...         ...          ...       ...          ...
# 2022 1              424          91          196        16          689
#      2             2195         659          534       196         3055
#      3            18769        5928         1501       922        20677
#      4            28652       10363         1457       613        28626
#      5           265241       91059          242       219       189444
#
# [110 rows x 5 columns]

# %%
v = vehicles.load()
v
# Out:
# Reading /Users/ryan/c/neighbor-ryan/nj-crashes/njdot/data/vehicles.parquet
#           crash_id  vn  ins_co owner_state             make   model color  \
# id
# 0                0   1     426          NJ    NISSAN MAXIMA           BUR
# 1                0   2     989          NJ  LINCOLN TOWNCAR            BK
# 2                1   1     962          NJ       TOYOTA 4DR           GRN
# 3                1   2    <NA>
# 4                2   1      85          NJ    CHEVY CORSICA           PUR
# ...            ...  ..     ...         ...              ...     ...   ...
# 11907735   6319791   1     413          NJ            MAZDA     TRI    GY
# 11907736   6319792   1     102          NJ           TOYOTA  TUNDRA    GN
# 11907737   6319792   2     100          NJ            HONDA     HRV    GY
# 11907738   6319793   1     426          NJ        CHEVROLET     TRA    RD
# 11907739   6319793   2    <NA>          PA             FORD  FUSION    SL
#
#             vy state  rm_by  impact_loc  damage_loc  type use  cargo_type  \
# id
# 0         1991    NJ   <NA>           8           7     1            <NA>
# 1         1996    NJ      2          12          12     6               0
# 2         1997    NJ      1          11        <NA>     1            <NA>
# 3            0         <NA>           0           0     5               0
# 4         1996    NJ      3           8          15     1            <NA>
# ...        ...   ...    ...         ...         ...   ...  ..         ...
# 11907735  2006    NJ      2          12          12     4  01        <NA>
# 11907736  2022    NJ      2           6           6     5  01        <NA>
# 11907737  2020    NJ      1          12          12     4  01        <NA>
# 11907738  2012    NJ      3          11          11     4  01        <NA>
# 11907739  2015    ME      3           1           1     1  01        <NA>
#
#           cir1  cir2  dir  act  ev1   ev2   ev3   ev4  oversize  hit_run  \
# id
# 0           25  <NA>    1    3   26  <NA>  <NA>  <NA>      <NA>    False
# 1            4  <NA>    2    3   26  <NA>  <NA>  <NA>         0    False
# 2           25  <NA>    3   10   28  <NA>  <NA>  <NA>      <NA>    False
# 3            2  <NA>    1    1   26  <NA>  <NA>  <NA>         0    False
# 4           25  <NA>    3    1   26     1  <NA>  <NA>      <NA>    False
# ...        ...   ...  ...  ...  ...   ...   ...   ...       ...      ...
# 11907735    52  <NA>    4    1   60  <NA>  <NA>  <NA>      <NA>    False
# 11907736    29  <NA>    2   12   26  <NA>  <NA>  <NA>      <NA>    False
# 11907737    29  <NA>    2   12   26  <NA>  <NA>  <NA>      <NA>    False
# 11907738     4  <NA>    3    6   26  <NA>  <NA>  <NA>      <NA>    False
# 11907739    25  <NA>    3    1   26  <NA>  <NA>  <NA>      <NA>    False
#
#           departure  damage    ev
# id
# 0                 1    <NA>  <NA>
# 1                 1    <NA>  <NA>
# 2                 1    <NA>  <NA>
# 3                 0    <NA>  <NA>
# 4                 6    <NA>  <NA>
# ...             ...     ...   ...
# 11907735          0       4    60
# 11907736          0       2    26
# 11907737          0       2    26
# 11907738          0       4    26
# 11907739          0       4    26
#
# [11907740 rows x 28 columns]

# %%
vm = v.merge(c, left_on='crash_id', right_index=True, how='left', validate='m:1')
vm['towed'] = vm.departure >= 3
vm['impounded'] = (vm.departure == 4) | (vm.departure == 5)
vm['driven'] = vm.departure == 1
vm['disabled'] = (vm.departure == 3) | (vm.departure == 5) | (vm.damage == 4)
vm['condition'] = vm.damage.fillna(0).astype(int)
vm['left'] = vm.departure == 2
vm.loc[vm.disabled, 'condition'] = 4
vm
# Out:
#           crash_id  vn  ins_co owner_state             make   model color  \
# id
# 0                0   1     426          NJ    NISSAN MAXIMA           BUR
# 1                0   2     989          NJ  LINCOLN TOWNCAR            BK
# 2                1   1     962          NJ       TOYOTA 4DR           GRN
# 3                1   2    <NA>
# 4                2   1      85          NJ    CHEVY CORSICA           PUR
# ...            ...  ..     ...         ...              ...     ...   ...
# 11907735   6319791   1     413          NJ            MAZDA     TRI    GY
# 11907736   6319792   1     102          NJ           TOYOTA  TUNDRA    GN
# 11907737   6319792   2     100          NJ            HONDA     HRV    GY
# 11907738   6319793   1     426          NJ        CHEVROLET     TRA    RD
# 11907739   6319793   2    <NA>          PA             FORD  FUSION    SL
#
#             vy state  rm_by  impact_loc  damage_loc  type use  cargo_type  \
# id
# 0         1991    NJ   <NA>           8           7     1            <NA>
# 1         1996    NJ      2          12          12     6               0
# 2         1997    NJ      1          11        <NA>     1            <NA>
# 3            0         <NA>           0           0     5               0
# 4         1996    NJ      3           8          15     1            <NA>
# ...        ...   ...    ...         ...         ...   ...  ..         ...
# 11907735  2006    NJ      2          12          12     4  01        <NA>
# 11907736  2022    NJ      2           6           6     5  01        <NA>
# 11907737  2020    NJ      1          12          12     4  01        <NA>
# 11907738  2012    NJ      3          11          11     4  01        <NA>
# 11907739  2015    ME      3           1           1     1  01        <NA>
#
#           cir1  cir2  dir  act  ev1   ev2   ev3   ev4  oversize  hit_run  \
# id
# 0           25  <NA>    1    3   26  <NA>  <NA>  <NA>      <NA>    False
# 1            4  <NA>    2    3   26  <NA>  <NA>  <NA>         0    False
# 2           25  <NA>    3   10   28  <NA>  <NA>  <NA>      <NA>    False
# 3            2  <NA>    1    1   26  <NA>  <NA>  <NA>         0    False
# 4           25  <NA>    3    1   26     1  <NA>  <NA>      <NA>    False
# ...        ...   ...  ...  ...  ...   ...   ...   ...       ...      ...
# 11907735    52  <NA>    4    1   60  <NA>  <NA>  <NA>      <NA>    False
# 11907736    29  <NA>    2   12   26  <NA>  <NA>  <NA>      <NA>    False
# 11907737    29  <NA>    2   12   26  <NA>  <NA>  <NA>      <NA>    False
# 11907738     4  <NA>    3    6   26  <NA>  <NA>  <NA>      <NA>    False
# 11907739    25  <NA>    3    1   26  <NA>  <NA>  <NA>      <NA>    False
#
#           departure  damage    ev     y   m  cc  mc severity  tk  ti  pk  pi  \
# id
# 0                 1    <NA>  <NA>  2001  12   1   1        p   0   0   0   0
# 1                 1    <NA>  <NA>  2001  12   1   1        p   0   0   0   0
# 2                 1    <NA>  <NA>  2001   1   1   1        p   0   0   0   0
# 3                 0    <NA>  <NA>  2001   1   1   1        p   0   0   0   0
# 4                 6    <NA>  <NA>  2001   4   1   1        i   0   4   0   0
# ...             ...     ...   ...   ...  ..  ..  ..      ...  ..  ..  ..  ..
# 11907735          0       4    60  2022  12  21  23        p   0   0   0   0
# 11907736          0       2    26  2022  12  21  23        p   0   0   0   0
# 11907737          0       2    26  2022  12  21  23        p   0   0   0   0
# 11907738          0       4    26  2022  12  21  23        i   0   1   0   0
# 11907739          0       4    26  2022  12  21  23        i   0   1   0   0
#
#           towed  impounded  driven  disabled  condition   left
# id
# 0         False      False    True      <NA>          0  False
# 1         False      False    True      <NA>          0  False
# 2         False      False    True      <NA>          0  False
# 3         False      False   False      <NA>          0  False
# 4          True      False   False      <NA>          0  False
# ...         ...        ...     ...       ...        ...    ...
# 11907735  False      False   False      True          4  False
# 11907736  False      False   False     False          2  False
# 11907737  False      False   False     False          2  False
# 11907738  False      False   False      True          4  False
# 11907739  False      False   False      True          4  False
#
# [11907740 rows x 43 columns]

# %%
cmymv = vm.groupby(cmym_cols)[['hit_run', 'towed', 'disabled']].sum()
cmymv
# Out:
#                hit_run  towed  disabled
# cc mc y    m
# 1  1  2001 1         0     14         0
#            2         0     10         0
#            3         0     22         0
#            4         0     27         0
#            5         0     10         0
# ...                ...    ...       ...
# 21 23 2022 8         0      0         3
#            9         0      0         3
#            10        1      1         9
#            11        0      1         4
#            12        1      1        13
#
# [138626 rows x 3 columns]

# %%
sql.write(
    cmymv, 'cmymv', CMYMC_DB,
    idxs=[cmym_cols],
    replace=False,
    # page_size=2**16,
)
# Out:
# Writing 138626 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cmymv)
# Wrote DB: 53936128 bytes
# After indices: 56360960 bytes

# %%
cmyv = sum_idx_col(cmymv, 'm', tbl_suffix='v')
cmyv
# Out:
# Writing 12275 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cmyv)
# Wrote DB: 57278464 bytes
# After indices: 57540608 bytes
#             hit_run  towed  disabled
# cc mc y
# 1  1  2001        0    193         0
#       2002        0    191         0
#       2003        0    238         0
#       2004        0    191         0
#       2005        0    181         0
# ...             ...    ...       ...
# 21 23 2018        4     99        99
#       2019        6     85        88
#       2020        7     65        66
#       2021        3     31        60
#       2022        3      6        72
#
# [12275 rows x 3 columns]

# %%
cymv = sum_idx_col(cmymv, 'mc', tbl_suffix='v')
cymv
# Out:
# Writing 5544 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cymv)
# Wrote DB: 57933824 bytes
# After indices: 58130432 bytes
#             hit_run  towed  disabled
# cc y    m
# 1  2001 1         0    343         0
#         2         0    419         0
#         3         0    314         0
#         4         0    332         0
#         5         0    350         0
# ...             ...    ...       ...
# 21 2022 8         7     37        76
#         9         7     42        79
#         10        7     32       101
#         11        6     31        93
#         12        7     42       122
#
# [5544 rows x 3 columns]

# %%
cyv = sum_idx_col(cymv, 'm', tbl_suffix='v')
cyv
# Out:
# Writing 462 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (cyv)
# Wrote DB: 58327040 bytes
# After indices: 58392576 bytes
#          hit_run  towed  disabled
# cc y
# 1  2001        0   4442         0
#    2002        0   4795         0
#    2003        0   5125         0
#    2004        0   5476         0
#    2005        0   5272         0
# ...          ...    ...       ...
# 21 2018      248   1957      2011
#    2019      270   1880      1936
#    2020      215   1422      1467
#    2021      202   1265      1615
#    2022      119    611      1243
#
# [462 rows x 3 columns]

# %%
ymv = sum_idx_col(cymv, 'cc', tbl_suffix='v')
ymv
# Out:
# Writing 264 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (ymv)
# Wrote DB: 58589184 bytes
# After indices: 58654720 bytes
#          hit_run  towed  disabled
# y    m
# 2001 1         0  11579         0
#      2         0   9624         0
#      3         0   9770         0
#      4         0   9166         0
#      5         0  10659         0
# ...          ...    ...       ...
# 2022 8      2454   6982      8734
#      9      2458   7409      9300
#      10     2728   8973     11653
#      11     2450   7911     10567
#      12     2448   8366     11013
#
# [264 rows x 3 columns]

# %%
yv = sum_idx_col(ymv, 'm', tbl_suffix='v', page_size=2**16)
yv
# Out:
# Writing 22 rows to /Users/ryan/c/neighbor-ryan/nj-crashes/www/public/njdot/cmymc.db (yv)
# Wrote DB: 58785792 bytes
# After indices: 58851328 bytes
# After setting page_size=65536 and vacuum: 57933824 bytes
#       hit_run   towed  disabled
# y
# 2001        0  129096         0
# 2002        0  136971         0
# 2003        0  139858         0
# 2004        0  141870         0
# 2005        0  138166         0
# 2006    39032  126134         0
# 2007    41291  128322         0
# 2008    40903  123938         0
# 2009    39749  122630         0
# 2010    39654  120327         0
# 2011    38673  116793         0
# 2012    36415  115394         0
# 2013    36942  116586         0
# 2014    37485  113974         0
# 2015    32668  116859         0
# 2016    33874  121459         0
# 2017    33624  121449    129716
# 2018    34325  124425    132189
# 2019    35334  120866    129221
# 2020    27712   93303    100024
# 2021    31396   96434    112571
# 2022    30565   90908    117126

# %%
import boto3
s3 = boto3.client('s3')

# %%
s3.upload_file(CMYMC_DB, Bucket='nj-crashes', Key=f'njdot/data/{basename(CMYMC_DB)}')
